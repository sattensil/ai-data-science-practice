# %%
import matplotlib as mpl

# %%
print("matplotlib version: ", mpl.__version__)
# Out:
# matplotlib version:  3.7.0

# %%
#%matplotlib inline use this if plot opens a new window called magic function 
#can't edit figure after generated with this method
# %matplotlib notebook 
#allows you to add features after figure is rendered
import matplotlib.pyplot as plt

# %%
plt.plot(5,5,'o')
#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.ylabel("Y")
plt.xlabel("X")
plt.title("Plotting Example"
# Out:
# Text(0.5, 1.0, 'Plotting Example')

# %%
import pandas as pd
  
# initialize list of lists
data = [[8880, 5123], [8670, 6682], [8147, 3308], [7338, 1863], [5704, 1527]]
  
# Create the pandas DataFrame
india_china_df = pd.DataFrame(data, columns=['India', 'China'])
india_china_df.index = [ [1980, 1981,1982,1983,1984]]
  
# print dataframe.
india_china_df
# Out:
#       India  China
# 1980   8880   5123
# 1981   8670   6682
# 1982   8147   3308
# 1983   7338   1863
# 1984   5704   1527

# %%
india_china_df.plot(kind="line")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Axes: >

# %%
india_china_df["India"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>
